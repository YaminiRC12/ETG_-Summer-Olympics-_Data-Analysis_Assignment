# %% [markdown]
# # **Summer Olympics Data Analysis Assignment**

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# ...

# %%
df.head()
# Out:
#    Year    City     Sport  ... Gender                       Event   Medal
# 0  1896  Athens  Aquatics  ...    Men              100M Freestyle    Gold
# 1  1896  Athens  Aquatics  ...    Men              100M Freestyle  Silver
# 2  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Silver
#
# [5 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       4
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %% [markdown]
# **1. In how many cities Summer Olympics is held so far?**

# %%
print('In',len(df['City'].unique()),"Cities Summer Olympics is held so far")
# Out:
# In 22 Cities Summer Olympics is held so far

# %% [markdown]
# **2. Which sport is having most number of Gold Medals so far? (Top 5)**

# %%
goldmedal_data=df[df['Medal']=="Gold"]
goldmedal_data.head()
# Out:
#     Year    City      Sport  ... Gender                       Event Medal
# 0   1896  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3   1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6   1896  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9   1896  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13  1896  Athens  Athletics  ...    Men                        100M  Gold
#
# [5 rows x 9 columns]

# %%
goldmedal_data['Sport'].unique() #display all unique sports
data=[] 
for sport in goldmedal_data['Sport'].unique():
  data.append([sport,len(goldmedal_data[goldmedal_data['Sport']==sport])])
data =pd.DataFrame(data,columns=['Sport','gold medal']) #to make dataframe we use DataFrame 
data=data.sort_values(by ='gold medal',ascending = False).head() #to sort the values i.e freq in descending manner
data.plot(x='Sport',y='gold medal',kind ='bar',figsize =(5,5)) #plot graph 
data.head()
# Out:
#          Sport  gold medal
# 0     Aquatics        1421
# 1    Athletics        1215
# 17      Rowing         890
# 4   Gymnastics         820
# 3      Fencing         552

# %% [markdown]
# **3. Which sport is having most number of medals so far? (Top 5)**

# %%
data=[]
for sport in df['Sport'].unique():
    data.append([sport,len(df[df['Sport']==sport])])
data=pd.DataFrame(data,columns=['Sport','Medals'])
data=data.sort_values(by='Medals',ascending=False).head(5)
data.plot(x='Sport',y='Medals',kind='bar',figsize=(5,5))
data.head()
# Out:
#          Sport  Medals
# 0     Aquatics    4170
# 1    Athletics    3638
# 17      Rowing    2667
# 4   Gymnastics    2307
# 3      Fencing    1613

# %% [markdown]
# **4. Which player has won most number of medals? (Top 5)**

# %%
data=[]
for athlete in df['Athlete'].unique():
    data.append([athlete,len(df[df['Athlete']==athlete])])
data=pd.DataFrame(data,columns=['Athlete','Medals'])
data=data.sort_values(by='Medals',ascending=False).head()
data.plot(x='Athlete',y='Medals',kind='bar',figsize=(5,5))
data.head()
# Out:
#                     Athlete  Medals
# 18640       PHELPS, Michael      22
# 7197       LATYNINA, Larisa      18
# 9948     ANDRIANOV, Nikolay      15
# 6591           ONO, Takashi      13
# 5103   MANGIAROTTI, Edoardo      13

# %% [markdown]
# **5. Which player has won most number Gold Medals of medals? (Top 5)**

# %%
data=[]
df=df[df['Medal']=='Gold']
for athlete in df['Athlete'].unique():
    data.append([athlete,len(df[df['Athlete']==athlete])])
data=pd.DataFrame(data,columns=['Athlete','Gold Medals'])
data=data.sort_values(by='Gold Medals',ascending=False).head(5)
data.plot(x='Athlete',y='Gold Medals',kind='bar',figsize=(5,5))
data.head()
# Out:
#                Athlete  Gold Medals
# 6851   PHELPS, Michael           18
# 3320       SPITZ, Mark            9
# 2714  LATYNINA, Larisa            9
# 4630       LEWIS, Carl            9
# 907       NURMI, Paavo            9

# %% [markdown]
# **6. In which year India won first Gold Medal in Summer Olympics?**

# %%
goldmedal_data=df[df['Medal']=="Gold"]
goldmedal_data
# Out:
#        Year    City      Sport  ... Gender                       Event Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6      1896  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9      1896  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13     1896  Athens  Athletics  ...    Men                        100M  Gold
# ...     ...     ...        ...  ...    ...                         ...   ...
# 31145  2012  London  Wrestling  ...    Men                    Wg 60 KG  Gold
# 31149  2012  London  Wrestling  ...    Men                    Wg 66 KG  Gold
# 31153  2012  London  Wrestling  ...    Men                    Wg 74 KG  Gold
# 31157  2012  London  Wrestling  ...    Men                    Wg 84 KG  Gold
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG  Gold
#
# [10486 rows x 9 columns]

# %%
goldmedal_data['Country'].unique()
goldmedalIndia=goldmedal_data[goldmedal_data["Country"]=="IND"]
goldmedalIndia=goldmedalIndia.sort_values(by="Year", ascending=True)
goldmedalIndia.head(1)
# Out:
#       Year       City   Sport Discipline  ... Country Gender   Event Medal
# 5512  1928  Amsterdam  Hockey     Hockey  ...     IND    Men  Hockey  Gold
#
# [1 rows x 9 columns]

# %% [markdown]
# **7. Which event is most popular in terms on number of players? (Top 5)**

# %%
data=[]
for players in df['Event'].unique():
    data.append([players,len(df[df['Event']==players])])
data=pd.DataFrame(data,columns=['Event','No.of.Players'])
data=data.sort_values(by='No.of.Players',ascending=False).head()
data.plot(x='Event',y='No.of.Players',kind='bar',figsize=(5,5))
data.head()
# Out:
#                 Event  No.of.Players
# 80           Football            503
# 176            Hockey            486
# 138  Team Competition            403
# 327        Basketball            342
# 50         Water Polo            325

# %% [markdown]
# **8. Which sport is having most female Gold Medalists? (Top 5)**

# %%
data=[]
df=df[df['Gender']=='Women']
df=df[df['Medal']=='Gold']
for sport in df['Sport'].unique():
    data.append([sport,len(df[df['Sport']==sport])])
data=pd.DataFrame(data,columns=['Sport','Female Player'])
data=data.sort_values(by='Female Player',ascending=False).head()
data.plot(x='Sport',y='Female Player',kind='bar',figsize=(5,5))
data.head(5)
# Out:
#          Sport  Female Player
# 4     Aquatics            589
# 7    Athletics            389
# 8   Gymnastics            268
# 14      Rowing            217
# 11  Volleyball            166
